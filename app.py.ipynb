# %%
import pandas as pd
from sklearn.cluster import KMeans
import joblib
import streamlit as st
import numpy as np
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, Float, String
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def load_data():
    url = "https://raw.githubusercontent.com/4GeeksAcademy/k-means-project-tutorial/main/housing.csv"
    df = pd.read_csv(url)
    return df
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
# Title and description
st.title("Housing Data Clustering")
st.write("This app clusters housing data using KMeans.")
# Out:
# 2024-10-19 00:09:20.264 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:09:20.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:09:20.268 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:09:20.268 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:09:20.269 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:09:20.270 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# Define the base for SQLAlchemy
Base = declarative_base()

# Define the ExampleModel class to represent the housing data
class HousingData(Base):
    __tablename__ = 'housing_data'
    
    id = Column(Integer, primary_key=True)
    longitude = Column(Float)
    latitude = Column(Float)
    housing_median_age = Column(Float)
    total_rooms = Column(Float)
    total_bedrooms = Column(Float)
    population = Column(Float)
    households = Column(Float)
    median_income = Column(Float)
    median_house_value = Column(Float)
# Out:
# /tmp/ipykernel_6533/1453761175.py:2: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %%
# Train K-Means model
def train_kmeans(X, n_clusters=3):
    kmeans = KMeans(n_clusters=n_clusters)
    kmeans.fit(X)
    return kmeans

# %%
# clean data
def clean_data(df):
    df_cleaned = df.dropna()
    return df_cleaned

# %%
# Streamlit app
def main():
    st.title("Housing Data K-Means Clustering App")

    # Load and display data
    df = load_data()
    st.subheader("Raw Housing Data")
    st.write(df.head())

    df_cleaned = clean_data(df)

    # Feature selection for K-Means
    st.sidebar.title("K-Means Settings")
    st.sidebar.subheader("Select number of clusters")
    num_clusters = st.sidebar.slider("Number of Clusters", 2, 10, 3)

    X = df_cleaned[['MedInc', 'Latitude', 'Longitude']]
    
    # Train the model
    model = train_kmeans(X, n_clusters=num_clusters)
    
    # Assign cluster labels to the data
    df_cleaned['Cluster'] = model.labels_

    st.subheader("K-Means Clustering Results")
    st.write(df_cleaned[['MedInc', 'Latitude', 'Longitude', 'Cluster']].head())

    # Plotting the clusters
    st.subheader("Cluster Visualization")
    fig, ax = plt.subplots()
    sns.scatterplot(data=df_cleaned, x='Longitude', y='Latitude', hue='Cluster', palette='viridis', ax=ax)
    plt.title("Clusters based on Longitude and Latitude")
    st.pyplot(fig)

    st.subheader("Explore the Clusters")
    cluster_choice = st.selectbox("Select a cluster to explore", df_cleaned['Cluster'].unique())
    st.write(df_cleaned[df_cleaned['Cluster'] == cluster_choice].head())

# Run the app
if __name__ == "__main__":
    main()
# Out:
# 2024-10-19 00:01:49.254 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:49.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:49.348 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:49.349 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:49.351 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:49.352 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:49.353 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:49.354 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:49.355 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:49.356 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:49.356 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:49.357 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:49.358 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:49.358 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:49.359 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:49.384 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:49.385 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:49.387 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:49.387 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:49.388 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:49.389 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:49.600 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:50.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:50.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:50.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:50.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:50.280 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:50.281 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:50.282 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:50.283 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:50.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:50.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:50.287 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-19 00:01:50.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# Select relevant features 
X = df_cleaned[['MedInc', 'Latitude', 'Longitude']]

# %%
# Train the model
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=3)

# %%
# Save the model
joblib.dump(kmeans, 'kmeans_model.pkl')
# Out:
# ['kmeans_model.pkl']

# %%
# Load the trained model
model = joblib.load('kmeans_model.pkl')

# %%
# Streamlit app title
st.title("Housing Clustering Application")
# Out:
# 2024-10-18 23:29:50.747 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-18 23:29:50.771
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/vscode/.local/lib/python3.10/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2024-10-18 23:29:50.772 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# Input fields
median_income = st.number_input("Median Income", min_value=0.0, max_value=20.0, step=0.1)
latitude = st.number_input("Latitude", min_value=32.0, max_value=42.0, step=0.1)
longitude = st.number_input("Longitude", min_value=-125.0, max_value=-114.0, step=0.1)
# Out:
# 2024-10-18 23:29:58.951 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-18 23:29:58.952 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-18 23:29:58.953 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-18 23:29:58.954 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-18 23:29:58.955 Session state does not function when running a script without `streamlit run`
# 2024-10-18 23:29:58.956 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-18 23:29:58.957 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-18 23:29:58.958 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-18 23:29:58.959 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-18 23:29:58.960 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-18 23:29:58.961 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-18 23:29:58.962 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-18 23:29:58.962 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-18 23:29:58.963 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-18 23:29:58.963 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-18 23:29:58.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-18 23:29:58.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-18 23:29:58.965 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-18 23:29:58.966 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# Predict cluster
if st.button("Predict Cluster"):
    user_input = np.array([[median_income, latitude, longitude]])
    cluster = model.predict(user_input)
    st.write(f"The data belongs to cluster: {cluster[0]}")
# Out:
# 2024-10-18 23:30:06.870 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-18 23:30:06.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-18 23:30:06.873 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-18 23:30:06.874 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-18 23:30:06.875 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
